# %%
import os
import sys
sys.path.append('../utils')
sys.path.append('../dataset0')
from data_loader import PeriodDataset
from tool import to_gpu
import torch
import torch.nn as nn

import numpy as np
import matplotlib.pyplot as plt

import types

# %matplotlib inline

# %%
# from basic_model import BasicRNN as Model
# from gated_model import GatedRNN as Model
from gated_model import StackGatedRNN as Model

# %%
PATH = '../runs/unemployment/'
run = 'stack_soft_1'

# %%
loader = PeriodDataset.get_loader(batch_size=3, N=30, W=10)
# Out:
# Data build range: [window(1980-12-31 00:00:00) - 1983-12-31 00:00:00, 2012-12-31 00:00:00]

# %%
trainX, trainY = loader.dataset.get_io('1977-01-01', '2012-12-31')
testX, testY = loader.dataset.get_io('1977-01-01', '2017-12-31')

# %%
with torch.no_grad():
    test_period_input = to_gpu(testX)
    self_test_input = to_gpu(testX[:trainX.size()[0] + 1])

# %%
self_test_input.shape
# Out:
# torch.Size([36, 12])

# %%
model = to_gpu(Model(seq_dim=12, hidden_size=24))
model.load_state_dict(torch.load(os.path.join(PATH, run, 'snapshots27.pth')))

# %%
test_period_output = model.forecast(test_period_input)
self_test_output = model.self_forecast(self_test_input, 5)

# %%
self_test_output
# Out:
# tensor([[ 3.6598,  3.3997,  3.2779,  3.1661,  3.2170,  4.1176,  4.3399,
#           4.2555,  3.8166,  3.4649,  3.3978,  3.2025],
#         [ 3.6526,  3.3578,  3.2736,  3.1671,  3.1902,  4.1331,  4.3856,
#           4.3262,  3.7845,  3.4556,  3.3403,  3.2384],
#         [ 3.6985,  3.4378,  3.3070,  3.2251,  3.2527,  4.2019,  4.4735,
#           4.3725,  3.8599,  3.5194,  3.4172,  3.2819],
#         [ 3.8912,  3.6022,  3.4532,  3.4032,  3.4187,  4.4053,  4.6676,
#           4.5708,  4.0568,  3.6853,  3.5891,  3.4391],
#         [ 3.9144,  3.6180,  3.4717,  3.4223,  3.4355,  4.4262,  4.6878,
#           4.5865,  4.0774,  3.7014,  3.6096,  3.4519],
#         [ 3.9301,  3.6354,  3.4851,  3.4363,  3.4513,  4.4443,  4.7054,
#           4.6058,  4.0950,  3.7149,  3.6253,  3.4645],
#         [ 3.8892,  3.5972,  3.4524,  3.4007,  3.4197,  4.4002,  4.6546,
#           4.5635,  4.0502,  3.6769,  3.5820,  3.4256],
#         [ 3.7628,  3.4820,  3.3446,  3.2913,  3.2936,  4.2684,  4.5091,
#           4.4422,  3.9148,  3.5684,  3.4616,  3.3115],
#         [ 3.7557,  3.4797,  3.3412,  3.2827,  3.2914,  4.2581,  4.5108,
#           4.4299,  3.9054,  3.5603,  3.4589,  3.3134],
#         [ 3.5489,  3.3020,  3.1749,  3.0934,  3.0989,  4.0446,  4.2950,
#           4.2340,  3.6972,  3.3939,  3.2579,  3.1600],
#         [ 3.4649,  3.2369,  3.1135,  3.0017,  3.0256,  3.9413,  4.1833,
#           4.1446,  3.5930,  3.3275,  3.1840,  3.0621],
#         [ 3.1682,  2.9486,  2.8797,  2.7216,  2.7545,  3.6124,  3.8352,
#           3.8435,  3.2694,  3.0456,  2.8845,  2.8108],
#         [ 3.1579,  2.9548,  2.8676,  2.7112,  2.7712,  3.5971,  3.8087,
#           3.8394,  3.2544,  3.0673,  2.8719,  2.8015],
#         [ 3.3419,  3.1181,  3.0151,  2.8820,  2.9194,  3.8006,  4.0321,
#           4.0134,  3.4482,  3.2212,  3.0692,  2.9622],
#         [ 3.6976,  3.4444,  3.2959,  3.2286,  3.2446,  4.2050,  4.4558,
#           4.3901,  3.8624,  3.5232,  3.4115,  3.2817],
#         [ 3.5814,  3.3216,  3.2133,  3.1012,  3.1182,  4.0649,  4.3082,
#           4.2584,  3.7047,  3.4120,  3.2867,  3.1659],
#         [ 3.3220,  3.0920,  3.0093,  2.8692,  2.9100,  3.7759,  4.0174,
#           3.9870,  3.4316,  3.1844,  3.0405,  2.9378],
#         [ 3.5026,  3.2514,  3.1520,  3.0255,  3.0899,  3.9706,  4.1981,
#           4.1588,  3.6302,  3.3378,  3.2050,  3.0781],
#         [ 3.3119,  3.0681,  3.0029,  2.8365,  2.8788,  3.7661,  3.9974,
#           3.9756,  3.4106,  3.1674,  3.0145,  2.9334],
#         [ 3.2657,  3.0376,  2.9655,  2.8194,  2.8727,  3.7167,  3.9479,
#           3.9321,  3.3674,  3.1465,  2.9815,  2.8924],
#         [ 3.0469,  2.8408,  2.8124,  2.5806,  2.6651,  3.4649,  3.6871,
#           3.6976,  3.1181,  2.9403,  2.7625,  2.7088],
#         [ 2.6534,  2.4852,  2.4833,  2.2366,  2.3217,  3.0500,  3.2491,
#           3.3194,  2.7249,  2.6149,  2.3792,  2.3805],
#         [ 2.3368,  2.2540,  2.2434,  1.8691,  2.0858,  2.6674,  2.8072,
#           2.9905,  2.3283,  2.3585,  2.0645,  2.0666],
#         [ 2.5180,  2.4265,  2.3866,  2.0015,  2.2692,  2.8527,  3.0161,
#           3.1684,  2.5097,  2.5621,  2.2727,  2.1649],
#         [ 3.0208,  2.8588,  2.7882,  2.5421,  2.6910,  3.4506,  3.6415,
#           3.6931,  3.1089,  2.9321,  2.7417,  2.6482],
#         [ 3.1542,  2.9584,  2.8905,  2.7008,  2.7585,  3.6078,  3.8363,
#           3.8217,  3.2328,  3.0454,  2.8772,  2.8150],
#         [ 3.2206,  2.9929,  2.9331,  2.7551,  2.8204,  3.6505,  3.8872,
#           3.8633,  3.3053,  3.1068,  2.9461,  2.8295],
#         [ 3.4013,  3.1576,  3.0656,  2.9486,  2.9820,  3.8711,  4.1192,
#           4.0755,  3.5203,  3.2514,  3.1117,  3.0300],
#         [ 2.8626,  2.6595,  2.6577,  2.4422,  2.4741,  3.2667,  3.5077,
#           3.5150,  2.9243,  2.7772,  2.5851,  2.5974],
#         [ 2.5061,  2.3877,  2.3851,  2.0836,  2.2463,  2.8777,  3.1013,
#           3.1493,  2.5460,  2.5377,  2.2593,  2.2434],
#         [ 3.0031,  2.8235,  2.7519,  2.5289,  2.6615,  3.4067,  3.6277,
#           3.6667,  3.0628,  2.9411,  2.7340,  2.6435],
#         [ 3.2847,  3.0526,  2.9874,  2.8211,  2.8733,  3.7287,  3.9779,
#           3.9395,  3.3767,  3.1431,  3.0135,  2.9205],
#         [ 3.7978,  3.5158,  3.3816,  3.3198,  3.3396,  4.2989,  4.5581,
#           4.4633,  3.9431,  3.6004,  3.5058,  3.3563],
#         [ 3.9599,  3.6589,  3.5093,  3.4636,  3.4769,  4.4755,  4.7417,
#           4.6370,  4.1256,  3.7380,  3.6550,  3.4931],
#         [ 3.8659,  3.5630,  3.4356,  3.3769,  3.3952,  4.3670,  4.6396,
#           4.5351,  4.0170,  3.6520,  3.5590,  3.4185],
#         [ 3.7781,  3.4871,  3.3709,  3.2983,  3.3306,  4.2760,  4.5354,
#           4.4444,  3.9275,  3.5750,  3.4728,  3.3374],
#         [ 3.6718,  3.3871,  3.2774,  3.1922,  3.2275,  4.1630,  4.4166,
#           4.3440,  3.8054,  3.4890,  3.3608,  3.2390],
#         [ 3.6710,  3.3955,  3.2788,  3.1949,  3.2201,  4.1610,  4.4121,
#           4.3351,  3.8060,  3.4871,  3.3715,  3.2357],
#         [ 3.6925,  3.4185,  3.2968,  3.2190,  3.2357,  4.1860,  4.4366,
#           4.3616,  3.8323,  3.5061,  3.3950,  3.2614],
#         [ 3.6663,  3.3914,  3.2752,  3.1929,  3.2134,  4.1572,  4.4081,
#           4.3373,  3.8036,  3.4826,  3.3661,  3.2395]], device='cuda:0')

# %%
self_test_output.shape
# Out:
# torch.Size([40, 12])

# %%
testY.shape
# Out:
# torch.Size([40, 12])

# %%
y_pred = torch.reshape(self_test_output.cpu(),(480,)).detach().numpy()
y = torch.reshape(testY,(480,)).numpy()

# %%
#开始画图

# %%
start_date = '1977-01-01'
x=np.linspace(1, 480, 480)
plt.figure(figsize=(20,6))
plt.plot(x, y, color='blue', label='Ground Truth')
plt.plot(x, y_pred, color='red', label='Prediction')

# plt.xticks(x)
# plt.xlim(0,23)
plt.legend(fontsize='large') # 显示图例

plt.title('Rolling forecasts')
plt.xlabel('Year',fontsize=13)
plt.ylabel('Unemployment',fontsize=13)

plt.grid(linestyle=':', linewidth=1)
# plt.savefig('./figures/Hour.jpg',bbox_inches='tight', dpi=400)

plt.show()

# %%
y_pred = torch.reshape(test_period_output.cpu(),(480,)).detach().numpy()
y = torch.reshape(testY,(480,)).numpy()

# %%
start_date = '1977-01-01'
x=np.linspace(1, 480, 480)
plt.figure(figsize=(20,6))
plt.plot(x, y, color='blue', label='Ground Truth')
plt.plot(x, y_pred, color='red', label='Prediction')

# plt.xticks(x)
# plt.xlim(0,23)
plt.legend(fontsize='large') # 显示图例

plt.title('Year forecasts')
plt.xlabel('Year',fontsize=13)
plt.ylabel('Unemployment',fontsize=13)

plt.grid(linestyle=':', linewidth=1)
# plt.savefig('./figures/Hour.jpg',bbox_inches='tight', dpi=400)

plt.show()

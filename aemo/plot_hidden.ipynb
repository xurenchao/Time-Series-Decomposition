# %%
import os
import sys
sys.path.append('utils')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import gridspec
import math
import types

# %matplotlib inline

# %%
h1 = np.loadtxt(open("./h_.csv", "rb"), delimiter = ",", skiprows = 0)
h2 = np.loadtxt(open("./h_s.csv", "rb"), delimiter = ",", skiprows = 0)

# %%
h1
# Out:
# array([-0.00449046,  0.01561338,  0.01339643, ...,  0.00792102,
#         0.00196632, -0.00063461])

# %%
h2
# Out:
# array([-0.00614609, -0.03752087, -0.02436116, ..., -0.04697789,
#        -0.0512204 , -0.05236859])

# %%
plt.figure(figsize=(12,5))
plt.xlim(0,200)
plt.plot(h1[100:300], 'r', label='GRU')
plt.plot(h2[100:300], 'g', label='GRU-S')
plt.legend(fontsize=12)

# plt.savefig('./figures/gru_hidden_state.jpg',bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(80,5))
plt.xlim(0,h1.shape[0])
plt.plot(h1, 'r', label='GRU')
plt.plot(h2, 'g', label='GRU-s')

# %%
s1 = np.loadtxt(open("./var_.csv", "rb"), delimiter = ",", skiprows = 0)
s2 = np.loadtxt(open("./var_s.csv", "rb"), delimiter = ",", skiprows = 0)

# %%
plt.figure(figsize=(100,5))
# plt.xlim(0,200)
plt.plot(s1, 'r', label='GRU')
plt.plot(s2, 'g', label='GRU-S')
plt.legend(fontsize=12)

# plt.savefig('./figures/gru_hidden_state.jpg',bbox_inches='tight')
plt.show()
